# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\waghb\OneDrive\Desktop\dsbdal\DSBDALExam DataSets\Adult\adult_dataset.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.columns = ["Age", "WorkClass", "fnlwgt", "Education", "Experience", "Marital-Status", "Occupation", "Relation","Race", "Gender", "Capital-Gain", "Capital-Loss", "Hours-Per-Week", "Country", "Target"]
df.head()
# Out:
#    Age  WorkClass  fnlwgt     Education  Experience      Marital-Status  \
# 0   25    Private  226802          11th           7       Never-married
# 1   38    Private   89814       HS-grad           9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm          12  Married-civ-spouse
# 3   44    Private  160323  Some-college          10  Married-civ-spouse
# 4   18          ?  103497  Some-college          10       Never-married
#
#           Occupation   Relation   Race  Gender  Capital-Gain  Capital-Loss  \
# 0  Machine-op-inspct  Own-child  Black    Male             0             0
# 1    Farming-fishing    Husband  White    Male             0             0
# 2    Protective-serv    Husband  White    Male             0             0
# 3  Machine-op-inspct    Husband  Black    Male          7688             0
# 4                  ?  Own-child  White  Female             0             0
#
#    Hours-Per-Week        Country Target
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# fnlwgt            0
# Education         0
# Experience        0
# Marital-Status    0
# Occupation        0
# Relation          0
# Race              0
# Gender            0
# Capital-Gain      0
# Capital-Loss      0
# Hours-Per-Week    0
# Country           0
# Target            0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (48842, 15)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_male = df[df["Gender"]==" Male"]
df_male
# Out:
# Empty DataFrame
# Columns: [Age, WorkClass, fnlwgt, Education, Experience, Marital-Status, Occupation, Relation, Race, Gender, Capital-Gain, Capital-Loss, Hours-Per-Week, Country, Target]
# Index: []

# %%
df_female = df[df["Gender"]==" Female"]
df_female
# Out:
# Empty DataFrame
# Columns: [Age, WorkClass, fnlwgt, Education, Experience, Marital-Status, Occupation, Relation, Race, Gender, Capital-Gain, Capital-Loss, Hours-Per-Week, Country, Target]
# Index: []

# %%
df["Country"].unique()
# Out:
# array(['United-States', '?', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df_country_India = df[df["Country"] == " India"]
df_country_India
# Out:
# Empty DataFrame
# Columns: [Age, WorkClass, fnlwgt, Education, Experience, Marital-Status, Occupation, Relation, Race, Gender, Capital-Gain, Capital-Loss, Hours-Per-Week, Country, Target]
# Index: []

# %%
df_merge_male_india = pd.concat([df_male,df_country_India])
df_merge_male_india
# Out:
# Empty DataFrame
# Columns: [Age, WorkClass, fnlwgt, Education, Experience, Marital-Status, Occupation, Relation, Race, Gender, Capital-Gain, Capital-Loss, Hours-Per-Week, Country, Target]
# Index: []

# %%
df_age = df.sort_values("Age")
df_age
# Out:
#        Age         WorkClass  fnlwgt     Education  Experience  \
# 33109   17           Private  244602          12th           8
# 33121   17           Private  108909       HS-grad           9
# 42116   17                 ?   64785          10th           6
# 42056   17           Private  239947          11th           7
# 9516    17                 ?  130969           9th           5
# ...    ...               ...     ...           ...         ...
# 22905   90           Private  313986          11th           7
# 13958   90           Private  272752  Some-college          10
# 34694   90           Private  313749     Bachelors          13
# 7414    90           Private  227796    Assoc-acdm          12
# 7419    90  Self-emp-not-inc  122348   Prof-school          15
#
#            Marital-Status       Occupation       Relation   Race  Gender  \
# 33109       Never-married    Other-service      Own-child  White    Male
# 33121       Never-married            Sales      Own-child  White  Female
# 42116       Never-married                ?      Own-child  White    Male
# 42056       Never-married     Adm-clerical      Own-child  White    Male
# 9516        Never-married                ?      Own-child  Black    Male
# ...                   ...              ...            ...    ...     ...
# 22905  Married-civ-spouse     Craft-repair        Husband  White    Male
# 13958       Never-married    Other-service      Own-child  White    Male
# 34694       Never-married   Prof-specialty      Own-child  White  Female
# 7414        Never-married  Exec-managerial  Not-in-family  White    Male
# 7419   Married-civ-spouse   Prof-specialty        Husband  White    Male
#
#        Capital-Gain  Capital-Loss  Hours-Per-Week        Country Target
# 33109             0             0              15  United-States  <=50K
# 33121             0             0              20  United-States  <=50K
# 42116             0             0              30  United-States  <=50K
# 42056             0             0              40  United-States  <=50K
# 9516              0             0              20  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 22905             0             0              40  United-States  <=50K
# 13958             0             0              10  United-States  <=50K
# 34694             0             0              10  United-States  <=50K
# 7414           6097             0              45  United-States   >50K
# 7419          20051             0              45  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
df_transpose = df.transpose()

# %%
df_transpose
# Out:
#                             0                   1                   2      \
# Age                            25                  38                  28
# WorkClass                 Private             Private           Local-gov
# fnlwgt                     226802               89814              336951
# Education                    11th             HS-grad          Assoc-acdm
# Experience                      7                   9                  12
# Marital-Status      Never-married  Married-civ-spouse  Married-civ-spouse
# Occupation      Machine-op-inspct     Farming-fishing     Protective-serv
# Relation                Own-child             Husband             Husband
# Race                        Black               White               White
# Gender                       Male                Male                Male
# Capital-Gain                    0                   0                   0
# Capital-Loss                    0                   0                   0
# Hours-Per-Week                 40                  50                  40
# Country             United-States       United-States       United-States
# Target                      <=50K               <=50K                >50K
#
#                              3              4              5      \
# Age                             44             18             34
# WorkClass                  Private              ?        Private
# fnlwgt                      160323         103497         198693
# Education             Some-college   Some-college           10th
# Experience                      10             10              6
# Marital-Status  Married-civ-spouse  Never-married  Never-married
# Occupation       Machine-op-inspct              ?  Other-service
# Relation                   Husband      Own-child  Not-in-family
# Race                         Black          White          White
# Gender                        Male         Female           Male
# Capital-Gain                  7688              0              0
# Capital-Loss                     0              0              0
# Hours-Per-Week                  40             30             30
# Country              United-States  United-States  United-States
# Target                        >50K          <=50K          <=50K
#
#                         6                   7              8      \
# Age                        29                  63             24
# WorkClass                   ?    Self-emp-not-inc        Private
# fnlwgt                 227026              104626         369667
# Education             HS-grad         Prof-school   Some-college
# Experience                  9                  15             10
# Marital-Status  Never-married  Married-civ-spouse  Never-married
# Occupation                  ?      Prof-specialty  Other-service
# Relation            Unmarried             Husband      Unmarried
# Race                    Black               White          White
# Gender                   Male                Male         Female
# Capital-Gain                0                3103              0
# Capital-Loss                0                   0              0
# Hours-Per-Week             40                  32             40
# Country         United-States       United-States  United-States
# Target                  <=50K                >50K          <=50K
#
#                              9      ...               48832  \
# Age                             55  ...                  32
# WorkClass                  Private  ...             Private
# fnlwgt                      104996  ...               34066
# Education                  7th-8th  ...                10th
# Experience                       4  ...                   6
# Marital-Status  Married-civ-spouse  ...  Married-civ-spouse
# Occupation            Craft-repair  ...   Handlers-cleaners
# Relation                   Husband  ...             Husband
# Race                         White  ...  Amer-Indian-Eskimo
# Gender                        Male  ...                Male
# Capital-Gain                     0  ...                   0
# Capital-Loss                     0  ...                   0
# Hours-Per-Week                  10  ...                  40
# Country              United-States  ...       United-States
# Target                       <=50K  ...               <=50K
#
#                              48833               48834               48835  \
# Age                             43                  32                  53
# WorkClass                  Private             Private             Private
# fnlwgt                       84661              116138              321865
# Education                Assoc-voc             Masters             Masters
# Experience                      11                  14                  14
# Marital-Status  Married-civ-spouse       Never-married  Married-civ-spouse
# Occupation                   Sales        Tech-support     Exec-managerial
# Relation                   Husband       Not-in-family             Husband
# Race                         White  Asian-Pac-Islander               White
# Gender                        Male                Male                Male
# Capital-Gain                     0                   0                   0
# Capital-Loss                     0                   0                   0
# Hours-Per-Week                  45                  11                  40
# Country              United-States              Taiwan       United-States
# Target                       <=50K               <=50K                >50K
#
#                           48836               48837               48838  \
# Age                          22                  27                  40
# WorkClass               Private             Private             Private
# fnlwgt                   310152              257302              154374
# Education          Some-college          Assoc-acdm             HS-grad
# Experience                   10                  12                   9
# Marital-Status    Never-married  Married-civ-spouse  Married-civ-spouse
# Occupation      Protective-serv        Tech-support   Machine-op-inspct
# Relation          Not-in-family                Wife             Husband
# Race                      White               White               White
# Gender                     Male              Female                Male
# Capital-Gain                  0                   0                   0
# Capital-Loss                  0                   0                   0
# Hours-Per-Week               40                  38                  40
# Country           United-States       United-States       United-States
# Target                    <=50K               <=50K                >50K
#
#                         48839          48840               48841
# Age                        58             22                  52
# WorkClass             Private        Private        Self-emp-inc
# fnlwgt                 151910         201490              287927
# Education             HS-grad        HS-grad             HS-grad
# Experience                  9              9                   9
# Marital-Status        Widowed  Never-married  Married-civ-spouse
# Occupation       Adm-clerical   Adm-clerical     Exec-managerial
# Relation            Unmarried      Own-child                Wife
# Race                    White          White               White
# Gender                 Female           Male              Female
# Capital-Gain                0              0               15024
# Capital-Loss                0              0                   0
# Hours-Per-Week             40             20                  40
# Country         United-States  United-States       United-States
# Target                  <=50K          <=50K                >50K
#
# [15 rows x 48842 columns]

# %%
df_melt = pd.melt(df,id_vars=["Education","Occupation"],value_name="value",var_name="Metric")
df_melt
# Out:
#            Education         Occupation  Metric  value
# 0               11th  Machine-op-inspct     Age     25
# 1            HS-grad    Farming-fishing     Age     38
# 2         Assoc-acdm    Protective-serv     Age     28
# 3       Some-college  Machine-op-inspct     Age     44
# 4       Some-college                  ?     Age     18
# ...              ...                ...     ...    ...
# 634941    Assoc-acdm       Tech-support  Target  <=50K
# 634942       HS-grad  Machine-op-inspct  Target   >50K
# 634943       HS-grad       Adm-clerical  Target  <=50K
# 634944       HS-grad       Adm-clerical  Target  <=50K
# 634945       HS-grad    Exec-managerial  Target   >50K
#
# [634946 rows x 4 columns]

# %%
df_cast = pd.pivot_table(df,index=["WorkClass","Occupation"],values="Hours-Per-Week")
df_cast
# Out:
#                                Hours-Per-Week
# WorkClass   Occupation
# ?           ?                       31.812433
# Federal-gov Adm-clerical            40.429158
#             Armed-Forces            41.600000
#             Craft-repair            40.892473
#             Exec-managerial         42.264925
# ...                                       ...
# Without-pay Handlers-cleaners       50.000000
#             Machine-op-inspct       32.500000
#             Other-service           32.500000
#             Sales                   45.000000
#             Transport-moving        20.000000
#
# [85 rows x 1 columns]
